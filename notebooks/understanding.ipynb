# %%
import pandas as pd

# %%
df = pd.read_csv("../data/my_data.csv")
df 

#df for the printing of the data in the csv file
# Out:
#    age category
# 0   18    young
# 1   25    young
# 2   22    young
# 3   35      old
# 4   42      old
# 5   55      old
# 6   19    young
# 7   38      old
# 8   30    young
# 9   60      old

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.countplot(x='category', data=df)
#sns for the bar chart
plt.title("How many young vs old?")

plt.show()
